# %% [markdown]
# # Tarea 1: Regresión Lineal
# ## Arantza Gomez Haro Gamboa

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np
from sklearn.metrics import r2_score

# %% [markdown]
# ## Datos:

# %%
df = pd.read_csv('housing.csv')
df['total_bedrooms'] = df['total_bedrooms'].fillna(0)
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
plt.scatter(df.median_income, df.median_house_value)

# %%
df = df[df.median_house_value != df.median_house_value.max()]
plt.scatter(df.median_house_value , df.median_income)

# %% [markdown]
# ## Regresiones lineales:

# %%
# housing median age
X = df[['housing_median_age']]
y = df['median_house_value']

model = linear_model.LinearRegression().fit(X, y)

print(r2_score(y_true = y, y_pred = model.predict(X)))
# Out:
# 0.004616870761555925

# %%
# total rooms
X = df[['total_rooms']]

model = linear_model.LinearRegression().fit(X, y)

print(r2_score(y_true = y, y_pred = model.predict(X)))
# Out:
# 0.020488694351853853

# %%
# total bedrooms
X = df[['total_bedrooms']]

model = linear_model.LinearRegression().fit(X, y)

print(r2_score(y_true = y, y_pred = model.predict(X)))
# Out:
# 0.005365082732013637

# %%
# population
X = df[['population']]

model = linear_model.LinearRegression().fit(X, y)

print(r2_score(y_true = y, y_pred = model.predict(X)))
# Out:
# 0.00014314747840926678

# %%
# households
X = df[['households']]

model = linear_model.LinearRegression().fit(X, y)

print(r2_score(y_true = y, y_pred = model.predict(X)))
# Out:
# 0.009004884338978392

# %%
# median income
X = df[['median_income']]

model = linear_model.LinearRegression().fit(X, y)

print(r2_score(y_true = y, y_pred = model.predict(X)))
# Out:
# 0.4129486198582022

# %% [markdown]
# ## Análisis:
#
# - Con las regresiones lineales hechas anteriormente, podemos ver que el modelo hecho con la variable numérica de **median income** es el que tiene mayor precisión, lo cuál nos permite tener una mejor predicción en cuestión del valor futuro de las casas. Es decir, esta variable cuenta con un valor de **R2 de 0.4129**, el cuál nos indica que el modelo hecho con median income tiene una precisión de aproximadamente 41%, siendo así el mejor modelo para realizar.
